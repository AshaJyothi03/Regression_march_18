# %% [markdown]
# <a href="https://colab.research.google.com/github/AshaJyothi03/Regression_march_18/blob/main/CLASSIFICATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #classification Algorithm:

# %% [markdown]
# #Decision tree Classifier
#   -single condition
#   -it is a supervised classifier and regressor model.
#   -it splits the data into subsets using the feactures that provides the highest information gain(or low)
#
#   #--consider dataset:
#   whether the student students wants to play outside based on whether conditions.
#
#
# DATASET:
# step1:
#   outlook:  sun sun overcast rainy rainy overcast
#   temp   :  hot hot mild     rain  rain  mild
#   humidity: hig hig nor      nor   nor   hig
#   windy   : F   F   T         T    T     F
#   PLAY    : N   N   Y         Y    Y     N
#
#
#   Step-02:
#     Compute entropy of target variable
#     H(S)=p1 log(p1)-p2 log(p2)
#
#     Where=p1=Probability of yes
#     p2=Probability of no
#
#     in out dataset
#     yes=3,no=3
#     H(S)=(3/6logbase2(3/6)) - (3/6 logbase2(3/6))=0.
#
#
#   step3: compute information gain for each outlook feature split by outlook
#   outlook: sunny  rainy  overcast
#   play yes:  0      2       1
#   play no :  2      0       1
#   total:     2      2       2
#
#   now we need to calculate entropy for each outlook
#
#   h(sunny)= 0/2 log(0/2) - 2/2 log(2/2) =0
#   h(rainy)= 2/2 log(2/2) - 0/2 log(0/2) =0
#   h(overcast) 1/2 log(1/2) -1/2 log(1/2) =0
#
#   step4: compute information gain for outlook formula
#
#   IG=h(s)-summation(P(i)*H(i))
#    IG  =0- [(3/6)*0 + (3/6)*0 +(3/6)*0]
#     IG =0
#
#   step5:compute information gain for other features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("playing.csv")
df
# Out:
#     OUTLOOK  TEMP   HUMDI  WINDY PLAY
# 0       sun   hot    high  False   no
# 1       sun   hot    high  False   no
# 2  overcast  mild  normal   True  yes
# 3     rainy  cool  normal   True  yes
# 4     rainy  cool  normal   True  yes
# 5  overcast  mild    high  False   no

# %%
label_encoders={}
for column in df:
  le=LabelEncoder()
  df[column]=le.fit_transform(df[column])
  label_encoders[column]=le
print(df)
# Out:
#    OUTLOOK  TEMP  HUMDI  WINDY  PLAY
# 0        2     1      0      0     0
# 1        2     1      0      0     0
# 2        0     2      1      1     1
# 3        1     0      1      1     1
# 4        1     0      1      1     1
# 5        0     2      0      0     0

# %%
#divide into input and output
x=df.drop("PLAY",axis=1)
y=df["PLAY"]
x
# Out:
#    OUTLOOK  TEMP  HUMDI  WINDY
# 0        2     1      0      0
# 1        2     1      0      0
# 2        0     2      1      1
# 3        1     0      1      1
# 4        1     0      1      1
# 5        0     2      0      0

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x,y)
y_pred=dt.predict(x)
y_pred
# Out:
# array([0, 0, 1, 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_pred)
# Out:
# 1.0

# %%
newdata=pd.DataFrame({"OUTLOOK":[1],"TEMP":[1],"HUMDI":[1],"WINDY":[0]})
y_pred=dt.predict(newdata)
y_pred
# Out:
# array([1])
